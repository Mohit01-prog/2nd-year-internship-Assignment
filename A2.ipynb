# %%
s="python is a programming language"
l=s.split()
print(l,type(l))
l.append("p")
l.insert(3,"for")
print(l)
l1=[1,2,3,4,5,6]
l.insert(0,l1)
print(l[0])
print(l[0][3])
ll=[9,8,7,6,5,4]
l.extend(ll)
print(l)
l.remove(8)
print(l)
l6=[2,3,4,5,6,"str"]
print(l6,type(l6))
l6.clear()
print(l6,type(l6))
lll=[1,2,3,4,5,6,7,8,9]
print(sum(lll,0),sum(lll,3))
# Out:
# ['python', 'is', 'a', 'programming', 'language'] <class 'list'>
# ['python', 'is', 'a', 'for', 'programming', 'language', 'p']
# [1, 2, 3, 4, 5, 6]
# 4
# [[1, 2, 3, 4, 5, 6], 'python', 'is', 'a', 'for', 'programming', 'language', 'p', 9, 8, 7, 6, 5, 4]
# [[1, 2, 3, 4, 5, 6], 'python', 'is', 'a', 'for', 'programming', 'language', 'p', 9, 7, 6, 5, 4]
# [2, 3, 4, 5, 6, 'str'] <class 'list'>
# [] <class 'list'>
# 45 48

# %%
x=("apple","tommy","jerry",911)
print(type(x))
print(x[0])
print(type(x[0]))
print(type(x[3]))


p=()
print(p)
print(type(p))


t = (1,4,5,6,0,9,8,7,8,2,3,8,0,9)

print(t)
print(type(t))

print("count of 0, 9, 3 respectively : \n")
print(t.count(0))
print(t.count(9))
print(t.count(3))


print("first index of 0, 8,3 respectively : \n")
print(t.index(0))
print(t.index(8))
print(t.index(3))

# print(t.index(12)) :- will give error as 12 not present in tuple 't'

print("index with range : ")  

print(t.index(9,6)) 

print(t[2])

print(t[10])



print(t[::-1])
print(t[-2:-10:-2])
print(t)
print(t[3:8])



t1 = (1, 2)
t2 = (3, 4)
print(t1 + t2)  # (1, 2, 3, 4)



print(t[2:10]*2)



print(t)
print(10 in t)
print(9 in t)

print(t)
print(len(t)) 


n=(4,3,10,9,5)
a,b,c,d,e= n
print(a,b,c,d,e)



pp=((1,2,3),(4,5,6,7),(8,9,0))

print(pp[1][3])



print("example : ")

tp=list(n)

print(tp)
print(tp.sort())
print(tp)
print(tp.reverse())
print(tp)

n=tuple(tp)
print(n)
# Out:
# <class 'tuple'>
# apple
# <class 'str'>
# <class 'int'>
# ()
# <class 'tuple'>
# (1, 4, 5, 6, 0, 9, 8, 7, 8, 2, 3, 8, 0, 9)
# <class 'tuple'>
# count of 0, 9, 3 respectively :
#
# 2
# 2
# 1
# first index of 0, 8 respectively :
#
# 4
# 6
# 10
# index with range :
# 13
# 5
# 3
# (9, 0, 8, 3, 2, 8, 7, 8, 9, 0, 6, 5, 4, 1)
# (0, 3, 8, 8)
# (1, 4, 5, 6, 0, 9, 8, 7, 8, 2, 3, 8, 0, 9)
# (6, 0, 9, 8, 7)
# (1, 2, 3, 4)
# (5, 6, 0, 9, 8, 7, 8, 2, 5, 6, 0, 9, 8, 7, 8, 2)
# (1, 4, 5, 6, 0, 9, 8, 7, 8, 2, 3, 8, 0, 9)
# False
# True
# (1, 4, 5, 6, 0, 9, 8, 7, 8, 2, 3, 8, 0, 9)
# 14
# 4 3 10 9 5
# 7
# example :
# [4, 3, 10, 9, 5]
# None
# [3, 4, 5, 9, 10]
# None
# [10, 9, 5, 4, 3]
# (10, 9, 5, 4, 3)

# %%
d = { 'name':"python", '2':"java",'3':'react','d2':{'speed':"rpm",'machine':"rotor"}}
print(d,type(d))
print(d['name'])
print(d ['d2']['speed'])


d = {}
d['al1'] = "11"
print(d,type(d))

d['al2'] = "22"
print(d,type(d))

del(d['al1'])
print(d,type(d))

dd={1:"q",2:"r",3:"s",4:"t"}
print(dd,type(dd))
print(dd.keys())
# Out:
# {'name': 'python', '2': 'java', '3': 'react', 'd2': {'speed': 'rpm', 'machine': 'rotor'}} <class 'dict'>
# python
# rpm
# {'al1': '11'} <class 'dict'>
# {'al1': '11', 'al2': '22'} <class 'dict'>
# {'al2': '22'} <class 'dict'>
# {1: 'q', 2: 'r', 3: 's', 4: 't'} <class 'dict'>
# dict_keys([1, 2, 3, 4])

# %%
fruits = {"apple", "banana", "mango"}

print("Set:", fruits)


fruits.add("orange")

print("Updated Set:", fruits)


fruits.add("apple")

print("After Adding Duplicate:", fruits)
# Out:
# Set: {'mango', 'banana', 'apple'}
# Updated Set: {'orange', 'mango', 'banana', 'apple'}
# After Adding Duplicate: {'orange', 'mango', 'banana', 'apple'}

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b
def multiply(a, b):
    return a * b
def divide(a, b):
    if b != 0:
        return a / b
    else:
        print("Zero as divisor is not allowed...")
def modulo(a, b):
    if b != 0:
     return a % b
    else:
     print("Zero as divisor is not allowed...")        

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
print("modulo =", modulo(num1, num2))
# Out:
# Addition = 15.0
# Subtraction = 5.0
# Multiplication = 50.0
# Division = 2.0
# modulo = 0.0

# %%
num = int(input("Enter the number: "))

p=num
numrev = 0
while p>0:
    d = p % 10
    numrev = 10 * numrev + d
    p //= 10

if numrev == num:
    print(f"{num} is a palindrome.")
else:
    print(f"{num} is not a palindrome.")
# Out:
# 12321 is a palindrome.
